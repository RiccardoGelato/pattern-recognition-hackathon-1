# %% [markdown]
# # 03 - Perceptron, MSE, and least squares
#
# Turn the multiclass problem into one-vs-rest or another justified multiclass formulation. Implement and compare linear decision rules.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

from src.utils import load_penguins

penguins = load_penguins()
# TODO: reproduce your selected preprocessing and split from Notebook 1.

# %%
# TODO: implement the perceptron update rule and define a stopping criterion.
# TODO: implement MSE/LSE linear discriminants, including the bias term.
# TODO: justify your multiclass coding scheme and compare the decision boundaries.
# TODO: study the effect of standardization and feature selection.
