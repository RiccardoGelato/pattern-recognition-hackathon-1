# %% [markdown]
# # 02 - Bayesian classification and density estimation
#
# Implement or choose generative density-based classifiers. Use the same preprocessing and train/test protocol for every method.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

from src.utils import load_penguins

penguins = load_penguins()
# TODO: reproduce your selected preprocessing and split from Notebook 1.
# Do not use the test set to estimate means, covariances, priors, or bandwidths.

# %%
# TODO: implement Bayes classification from class priors and class-conditional densities.
# Compare diagonal, shared, and class-specific Gaussian covariance assumptions.
# TODO: implement a Parzen estimator, evaluate several bandwidths, and explain bias/variance.
# TODO: report accuracy, macro F1, confusion matrices, and at least one failure case.
