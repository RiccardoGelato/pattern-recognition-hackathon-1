# %% [markdown]
# # 04 - SVMs and shallow neural networks
#
# Apply margin-based and shallow nonlinear classifiers to the Palmer Penguins task: predict `species` from the features and preprocessing protocol you established earlier.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

import numpy as np
import pandas as pd
from src.utils import NUMERIC_FEATURES, TARGET, load_penguins

penguins = load_penguins()
# TODO: reproduce the preprocessing and split you justified in Notebook 1.
# Keep a final test set untouched while selecting hyperparameters.

# TODO: create a results table with columns such as method, settings, accuracy, and macro_f1.

# %%
# SVM experiment
# TODO: implement or use a linear SVM and an SVM with a nonlinear kernel.
# TODO: investigate C and, where relevant, gamma using training-only validation.
# TODO: inspect support vectors and explain how the margin changes.
# TODO: evaluate on the untouched test set only after model selection.

# %%
# Shallow neural-network experiment
# TODO: implement or use a single-layer neural classifier as a linear reference.
# TODO: implement or use a one-hidden-layer network on the Penguins data.
# TODO: compare at least two activation functions and vary hidden-layer width.
# TODO: record initialization, stopping criteria, and training behavior.
# TODO: compare its errors with the SVM errors using the same test set.
