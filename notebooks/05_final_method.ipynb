# %% [markdown]
# # 05 - Final method and experimental report
#
# This is your open-ended method notebook. Choose one method, extension, or research question that is justified by the structure of the Penguins dataset and by your results in Notebooks 1-4.
#
# Your work should be reproducible and should use the same untouched test set when comparing against earlier methods.

# %% [markdown]
# ## Possible directions
#
# Choose one direction or propose your own:
#
# - Include `island` or `sex` and discuss categorical encoding and scientific interpretation.
# - Build a nonlinear feature map and compare it with an RBF SVM or shallow network.
# - Study imputation, missingness indicators, or deliberately incomplete measurements.
# - Investigate class imbalance, priors, and macro F1.
# - Implement one course method from scratch and compare it with a library implementation.
# - Analyze uncertainty, decision scores, or examples where models disagree.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

import pandas as pd
from src.utils import load_penguins

penguins = load_penguins()
# TODO: state your research question and chosen target/features.
# TODO: reproduce your preprocessing without leaking test-set information.
# TODO: define the fixed split or cross-validation protocol.

# %%
# TODO: implement or fit your selected method.
# TODO: tune hyperparameters using training data only.
# TODO: compare with at least two methods from the earlier notebooks.
# TODO: collect accuracy, macro F1, confusion matrices, and relevant plots.
